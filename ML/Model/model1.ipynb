# %% [markdown]
# PKL dan JSON

# %% [markdown]
# latih Model

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from joblib import dump
import json
import numpy as np
import pickle

# Load data dengan pengecekan error sederhana
try:
    df = pd.read_csv("gabungan_dataset_lengkap.csv")
except FileNotFoundError:
    print("File gabungan_dataset_lengkap.csv tidak ditemukan.")
    exit()

# Drop baris dengan target kosong
df.dropna(subset=['prognosis'], inplace=True)

# Pisahkan fitur dan label
X = df.drop(columns=['prognosis'])
y = df['prognosis']

# Encode fitur kategorikal (pastikan fitur kategorikal memang perlu encode)
for col in X.columns:
    if X[col].dtype == 'object':
        le_feat = LabelEncoder()
        X[col] = le_feat.fit_transform(X[col].astype(str))

# Encode label prognosis
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Simpan daftar fitur ke JSON
feature_columns = list(X.columns)
with open('feature_columns.json', 'w') as f:
    json.dump(feature_columns, f)

# Simpan mapping label ke JSON (mapping index ke label string)
label_mapping = {int(i): label for i, label in enumerate(le.classes_)}
with open('label_mapping.json', 'w') as f:
    json.dump(label_mapping, f)

# Split data train-test
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42
)

# Latih model RandomForest
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Evaluasi model
y_pred = model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")

# Tampilkan classification report hanya untuk label yang muncul
unique_labels = np.unique(y_test)
target_names = [le.classes_[i] for i in unique_labels]
print(classification_report(y_test, y_pred, labels=unique_labels, target_names=target_names, zero_division=0))

# Simpan model dan label encoder juga sebagai .pkl dan .joblib (optional)
with open('randomforest_model.pkl', 'wb') as f:
    pickle.dump(model, f)
with open('label_encoder.pkl', 'wb') as f:
    pickle.dump(le, f)

# Simpan juga model dan encoder dengan joblib, kalau mau
dump(model, 'randomforest_model.joblib')
dump(le, 'label_encoder.joblib')

print("Model, label encoder, dan mapping label berhasil disimpan dalam file .pkl, .joblib, dan .json.")
# Out:
# Accuracy: 0.9763
#                                              precision    recall  f1-score   support
#
#                           Cedera ke pinggul       1.00      1.00      1.00         3
#                Gangguan kelenjar salivarium       1.00      1.00      1.00         8
#                          Gangguan metabolis       1.00      1.00      1.00         7
#                       Gangguan nyeri kronis       0.97      0.95      0.96       134
#                            Pankreatsis akut       0.97      0.98      0.98       111
#                                 atelektasis       1.00      1.00      1.00        22
#                          atrophic vaginitis       0.93      0.99      0.96        67
#                             cedera di lutut       0.93      1.00      0.96        13
#                            cedera di tangan       0.97      0.97      0.97        31
#                                cedera perut       1.00      1.00      1.00        10
#                                    cirhosis       1.00      1.00      1.00        57
#                              cryptorchidism       1.00      1.00      1.00         1
#                         diabetes retinopati       0.93      0.92      0.92        83
#                                fibromyalgia       0.95      0.98      0.96       122
#                              fraktur tangan       0.96      0.96      0.96        27
#                              gangguan makan       1.00      0.99      1.00       103
#                              gangguan panik       0.99      0.99      0.99       189
#                      gangguan perataan mata       1.00      1.00      1.00        85
#                                    glaukoma       0.94      0.95      0.94       111
#                           iskemia dari usus       1.00      0.98      0.99        56
#                                 kanker hati       1.00      0.78      0.88         9
#            keracunan karena ethylene glycol       0.80      1.00      0.89         4
#                          kolekocholithiasis       0.99      1.00      0.99        86
#                        luka manset berputar       1.00      1.00      1.00        23
#                    masalah selama kehamilan       0.98      0.98      0.98       172
#                              osteokondrosis       1.00      0.96      0.98        26
#                         pendarahan subdural       1.00      1.00      1.00        28
#                                 peritonitis       0.91      0.95      0.93        73
#                            polip pita suara       1.00      1.00      1.00        15
#                              pyelonephritis       0.96      0.97      0.97       173
#         sakit kepala setelah tusukan lumbar       1.00      0.97      0.98        33
#                selulit atau kepompong mulut       1.00      1.00      1.00        29
#                  serangan iskemik sementara       1.00      1.00      1.00       131
#                         sindrom sinus sakit       1.00      0.97      0.99        36
#                            stenosis pyloric       1.00      1.00      1.00         5
# tinnitus dari penyebab yang tidak diketahui       1.00      1.00      1.00        61
#                     toracic aortic aneurysm       1.00      0.95      0.98        43
#                                   vaginitis       0.99      0.97      0.98       179
#
#                                    accuracy                           0.98      2366
#                                   macro avg       0.98      0.98      0.98      2366
#                                weighted avg       0.98      0.98      0.98      2366
#
# Model, label encoder, dan mapping label berhasil disimpan dalam file .pkl, .joblib, dan .json.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_val_score
from sklearn.metrics import accuracy_score, classification_report
from imblearn.over_sampling import SMOTE
from collections import Counter
import json
import pickle

# Load data
try:
    df = pd.read_csv("gabungan_dataset_lengkap.csv")
except FileNotFoundError:
    print("File gabungan_dataset_lengkap.csv tidak ditemukan.")
    exit()

# Drop baris dengan target kosong
df.dropna(subset=['prognosis'], inplace=True)

# Hapus kelas dengan kurang dari 2 data supaya stratify bisa jalan
counts = df['prognosis'].value_counts()
rare_classes = counts[counts < 2].index
if len(rare_classes) > 0:
    print(f"Menghapus kelas dengan sangat sedikit data: {list(rare_classes)}")
    df = df[~df['prognosis'].isin(rare_classes)]

# Pisahkan fitur dan label
X = df.drop(columns=['prognosis'])
y = df['prognosis']

# Pastikan fitur numerik, encode fitur kategorikal jika ada
for col in X.columns:
    if X[col].dtype == 'object':
        le_feat = LabelEncoder()
        X[col] = le_feat.fit_transform(X[col].astype(str))

# Encode label prognosis
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Pastikan data numpy array
X_np = X.values

# Cek distribusi kelas
class_counts = Counter(y_encoded)
min_class_count = min(class_counts.values())
print(f"Jumlah data terkecil pada kelas: {min_class_count}")

if min_class_count <= 1:
    print("Tidak cukup data pada kelas minoritas setelah filter. Tambah data atau hapus kelas minoritas.")
    exit()

# Set k_neighbors SMOTE adaptif
k_neighbors = min(5, min_class_count - 1)
print(f"SMOTE akan menggunakan k_neighbors={k_neighbors}")

# Terapkan SMOTE oversampling
smote = SMOTE(random_state=42, k_neighbors=k_neighbors)
X_resampled, y_resampled = smote.fit_resample(X_np, y_encoded)

print(f"Data setelah SMOTE, jumlah contoh: {len(y_resampled)}")
print(pd.Series(y_resampled).value_counts())

# Latih model sementara untuk feature importance
model_rf_temp = RandomForestClassifier(n_estimators=100, random_state=42)
model_rf_temp.fit(X_resampled, y_resampled)

importances = model_rf_temp.feature_importances_

# Pilih fitur penting yang importancenya >= median (atau ganti threshold sesuai kebutuhan)
threshold = np.median(importances)
important_indices = np.where(importances >= threshold)[0]
selected_features = X.columns[important_indices]

print(f"Memilih fitur penting sebanyak: {len(selected_features)}")

X_resampled_selected = X_resampled[:, important_indices]

# Split train-test dengan stratify
X_train, X_test, y_train, y_test = train_test_split(
    X_resampled_selected, y_resampled, test_size=0.2, random_state=42, stratify=y_resampled
)

# Hyperparameter tuning RandomForest dengan RandomizedSearchCV
param_dist = {
    'n_estimators': [100, 200, 300, 400],
    'max_depth': [None, 10, 20, 30, 40],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

rf = RandomForestClassifier(random_state=42, n_jobs=-1)
random_search = RandomizedSearchCV(
    rf, param_distributions=param_dist, n_iter=30, cv=5,
    scoring='accuracy', random_state=42, n_jobs=-1, verbose=1
)
random_search.fit(X_train, y_train)

print(f"Best parameters: {random_search.best_params_}")
print(f"Best CV score: {random_search.best_score_:.4f}")

best_model = random_search.best_estimator_

# Evaluasi model pada test set
y_pred = best_model.predict(X_test)
print(f"Accuracy test set: {accuracy_score(y_test, y_pred):.4f}")
print(classification_report(y_test, y_pred, target_names=le.classes_, zero_division=0))

# Cross-validation score untuk stabilitas model
cv_scores = cross_val_score(best_model, X_resampled_selected, y_resampled, cv=5, n_jobs=-1)
print(f"Cross-validation accuracy scores: {cv_scores}")
print(f"Mean CV accuracy: {cv_scores.mean():.4f}")

# Simpan model, label encoder, dan fitur terpilih
with open('randomforest_model.pkl', 'wb') as f:
    pickle.dump(best_model, f)

with open('label_encoder.pkl', 'wb') as f:
    pickle.dump(le, f)

with open('selected_features.json', 'w') as f:
    json.dump(list(selected_features), f)

# Simpan metadata training
info = {
    "k_neighbors_smote": k_neighbors,
    "num_features_before": X.shape[1],
    "num_features_after": len(selected_features),
    "num_samples_before": len(y_encoded),
    "num_samples_after": len(y_resampled),
    "best_params": random_search.best_params_
}
with open('training_info.json', 'w') as f:
    json.dump(info, f)

print("Model, label encoder, fitur penting, dan metadata berhasil disimpan.")
# Out:
# Menghapus kelas dengan sangat sedikit data: ['sindrom turner']
# Jumlah data terkecil pada kelas: 5
# SMOTE akan menggunakan k_neighbors=4
# Data setelah SMOTE, jumlah contoh: 35607
# 16    913
# 28    913
# 11    913
# 21    913
# 6     913
# 14    913
# 31    913
# 17    913
# 30    913
# 35    913
# 1     913
# 25    913
# 7     913
# 2     913
# 38    913
# 34    913
# 36    913
# 18    913
# 15    913
# 32    913
# 29    913
# 23    913
# 3     913
# 24    913
# 20    913
# 5     913
# 8     913
# 22    913
# 0     913
# 10    913
# 37    913
# 26    913
# 12    913
# 13    913
# 19    913
# 33    913
# 27    913
# 9     913
# 4     913
# Name: count, dtype: int64
# Memilih fitur penting sebanyak: 500
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Best parameters: {'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_depth': 40, 'bootstrap': False}
# Best CV score: 0.9929
# Accuracy test set: 0.9914
#                                              precision    recall  f1-score   support
#
#                           Cedera ke pinggul       1.00      0.99      0.99       183
#                Gangguan kelenjar salivarium       1.00      0.99      0.99       183
#                          Gangguan metabolis       1.00      1.00      1.00       183
#                       Gangguan nyeri kronis       1.00      0.96      0.98       183
#                            Pankreatsis akut       0.99      0.99      0.99       182
#                                 atelektasis       1.00      1.00      1.00       183
#                          atrophic vaginitis       0.98      0.99      0.99       182
#                             cedera di lutut       1.00      1.00      1.00       183
#                            cedera di tangan       0.96      0.98      0.97       182
#                                cedera perut       0.99      1.00      1.00       183
#                                    cirhosis       1.00      1.00      1.00       183
#                              cryptorchidism       1.00      1.00      1.00       183
#                         diabetes retinopati       0.99      0.90      0.94       182
#                                fibromyalgia       0.96      1.00      0.98       182
#                              fraktur tangan       0.98      0.96      0.97       183
#                              gangguan makan       0.99      0.99      0.99       182
#                              gangguan panik       1.00      0.99      0.99       182
#                      gangguan perataan mata       1.00      1.00      1.00       182
#                                    glaukoma       0.91      0.99      0.95       183
#                           iskemia dari usus       0.99      1.00      0.99       182
#                                 kanker hati       1.00      1.00      1.00       183
#            keracunan karena ethylene glycol       0.99      1.00      0.99       183
#                          kolekocholithiasis       0.99      0.99      0.99       183
#                        luka manset berputar       1.00      1.00      1.00       183
#                    masalah selama kehamilan       0.99      1.00      0.99       182
#                              osteokondrosis       1.00      1.00      1.00       183
#                         pendarahan subdural       1.00      0.99      1.00       182
#                                 peritonitis       0.99      0.99      0.99       182
#                            polip pita suara       0.99      1.00      0.99       183
#                              pyelonephritis       0.98      0.98      0.98       183
#         sakit kepala setelah tusukan lumbar       1.00      1.00      1.00       182
#                selulit atau kepompong mulut       1.00      1.00      1.00       183
#                  serangan iskemik sementara       0.99      1.00      1.00       183
#                       sindrom alkohol janin       1.00      1.00      1.00       182
#                         sindrom sinus sakit       1.00      1.00      1.00       183
#                            stenosis pyloric       1.00      1.00      1.00       183
# tinnitus dari penyebab yang tidak diketahui       1.00      1.00      1.00       182
#                     toracic aortic aneurysm       1.00      1.00      1.00       183
#                                   vaginitis       0.99      0.97      0.98       183
#
#                                    accuracy                           0.99      7122
#                                   macro avg       0.99      0.99      0.99      7122
#                                weighted avg       0.99      0.99      0.99      7122
#
# Cross-validation accuracy scores: [0.98778433 0.99129458 0.9933998  0.99410195 0.99494453]
# Mean CV accuracy: 0.9923
# Model, label encoder, fitur penting, dan metadata berhasil disimpan.

# %%
import json
import pandas as pd
import pickle

# Load model dan label encoder dari pkl
with open('randomforest_model.pkl', 'rb') as f:
    model = pickle.load(f)

with open('label_encoder.pkl', 'rb') as f:
    le = pickle.load(f)

# Load fitur kolom penting yang dipakai model (hasil feature selection)
with open('selected_features.json', 'r') as f:
    feature_columns = json.load(f)

answer = input("Apakah Anda ingin memasukkan gejala? (Ya/Tidak): ").strip().lower()

if answer == 'ya':
    print("\nPilih gejala yang Anda alami:")
    for i, feat in enumerate(feature_columns, 1):
        print(f"{i}. {feat}")

    input_str = input("\nMasukkan nomor gejala (pisahkan dengan koma): ")
    selected_indices = [int(x.strip()) - 1 for x in input_str.split(",") if x.strip().isdigit()]

    # Buat dict input dengan default 0
    input_dict = {feat: 0 for feat in feature_columns}
    for idx in selected_indices:
        if 0 <= idx < len(feature_columns):
            input_dict[feature_columns[idx]] = 1

    input_vector = [input_dict[col] for col in feature_columns]
    input_df = pd.DataFrame([input_vector], columns=feature_columns)

    # Prediksi
    pred_encoded = model.predict(input_df)[0]
    pred_label = le.inverse_transform([pred_encoded])[0]

    print("\n=== Hasil Prediksi Penyakit ===")
    print(f"Penyakit yang diprediksi: {pred_label.upper()}")

else:
    print("Baik, tidak ada input gejala diberikan. Program selesai.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[80], line 16
#      13 with open('selected_features.json', 'r') as f:
#      14     feature_columns = json.load(f)
# ---> 16 answer = input("Apakah Anda ingin memasukkan gejala? (Ya/Tidak): ").strip().lower()
#      18 if answer == 'ya':
#      19     print("\nPilih gejala yang Anda alami:")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# Prediksi

# %%
import json
import pandas as pd
import pickle

# Load model dan label encoder dari pkl
with open('randomforest_model.pkl', 'rb') as f:
    model = pickle.load(f)

with open('label_encoder.pkl', 'rb') as f:
    le = pickle.load(f)

# Load fitur kolom dari JSON
with open('feature_columns.json', 'r') as f:
    feature_columns = json.load(f)

# Tanya user mau input gejala atau tidak
answer = input("Apakah Anda ingin memasukkan gejala? (Ya/Tidak): ").strip().lower()

if answer == 'ya':
    print("\nPilih gejala yang Anda alami:")
    for i, feat in enumerate(feature_columns, 1):
        print(f"{i}. {feat}")

    input_str = input("\nMasukkan nomor gejala (pisahkan dengan koma): ")
    selected_indices = [int(x.strip()) - 1 for x in input_str.split(",") if x.strip().isdigit()]

    # Buat dictionary fitur dengan nilai default 0
    input_dict = {feat: 0 for feat in feature_columns}
    for idx in selected_indices:
        if 0 <= idx < len(feature_columns):
            input_dict[feature_columns[idx]] = 1

    # Buat dataframe dari input
    input_vector = [input_dict[col] for col in feature_columns]
    input_df = pd.DataFrame([input_vector], columns=feature_columns)

    # Prediksi
    predicted_class_index = model.predict(input_df)[0]
    predicted_label = le.inverse_transform([predicted_class_index])[0]

    print("\n=== Hasil Prediksi Penyakit ===")
    print(f"Penyakit yang diprediksi: {predicted_label.upper()}")

else:
    print("Baik, tidak ada input gejala diberikan. Program selesai.")
# Out:
# Pilih gejala yang Anda alami:
# 1. gelisah dan gugup
# 2. depresi
# 3. Kekeringan napas
# 4. depresif atau gejala psikotik
# 5. nyeri dada tajam
# 6. pusing
# 7. insomnia
# 8. gerakan abnormal tidak disengaja
# 9. dada tilf
# 10. papitasi
# 11. detak jantung tidak teratur
# 12. bernafas dengan cepat
# 13. suara serak
# 14. sakit tenggorokan
# 15. kesulitan berbicara
# 16. batuk
# 17. kemacetan hidung
# 18. tenggorokan pembengkakan
# 19. pendengaran berkurang
# 20. benjolan di tenggorokan
# 21. Tenggorokan terasa ketat
# 22. kesulitan menelan
# 23. pembengkakan kulit
# 24. retensi urin
# 25. groin massa
# 26. sakit kaki
# 27. hip pain
# 28. nyeri suprapubic
# 29. darah di bangku
# 30. kekurangan pertumbuhan
# 31. gejala emosional
# 32. kelemahan siku
# 33. kembali kelemahan
# 34. pus dalam sputum
# 35. gejala skrotum dan testis
# 36. pembengkakan skrotum
# 37. nyeri di testis
# 38. datar
# 39. nanah dari telinga
# 40. kuning
# 41. massa dalam skrotum
# 42. putih debit dari mata
# 43. bayi yang mudah marah
# 44. penyalahgunaan alkohol
# 45. pingsan
# 46. perilaku bermusuhan
# 47. penyalahgunaan obat
# 48. sakit perut yang tajam
# 49. merasa sakit
# 50. muntah
# 51. sakit kepala
# 52. mual
# 53. diare
# 54. vagina gatal
# 55. vaginal dryness
# 56. urinasi menyakitkan
# 57. urinasi involuntary
# 58. rasa sakit selama hubungan seksual
# 59. sering urinasi
# 60. Bawah sakit perut
# 61. debit vagina
# 62. darah dalam urin
# 63. panas berkedip
# 64. perdarahan intermentum
# 65. Tangan atau jari sakit
# 66. sakit pergelangan tangan
# 67. tangan atau jari bengkak
# 68. sakit lengan
# 69. pembengkakan pergelangan tangan
# 70. kaku lengan atau tiffness
# 71. pembengkakan lengan
# 72. tangan atau jari kaku atau tiffness
# 73. Pergelangan tangan kaku atau kaku
# 74. bibir pembengkakan
# 75. Sakit gigi
# 76. kulit muncul abnormal
# 77. lesi kulit
# 78. jerawat atau jerawat
# 79. bibir kering
# 80. Sakit wajah
# 81. mulut sakit
# 82. pertumbuhan kulit
# 83. deviasi mata
# 84. pandangan berkurang
# 85. pandangan ganda
# 86. juling-juling
# 87. gejala mata
# 88. rasa sakit di mata
# 89. mata bergerak tidak normal
# 90. gerakan normal kelopak mata
# 91. asing tubuh sensasi di mata
# 92. tidak teratur muncul kulit kepala
# 93. kelenjar getah bening bengkak
# 94. sakit punggung
# 95. Sakit leher
# 96. sakit punggung rendah
# 97. rasa sakit anus
# 98. rasa sakit selama kehamilan
# 99. Sakit panggul
# 100. Impotensi
# 101. bayi meludah
# 102. muntah darah
# 103. muntah.1
# 104. Membakar sakit perut
# 105. Kegelisahan
# 106. gejala bayi
# 107. Wheezing
# 108. edema periferal
# 109. massa leher
# 110. sakit telinga
# 111. rahang bengkak
# 112. mulut kering
# 113. pembengkakan leher
# 114. sakit lutut
# 115. kaki atau kaki sakit
# 116. Bowlegged atau knock- kneed
# 117. sakit pergelangan kaki
# 118. Tulang yang menyakitkan
# 119. kelemahan lutut
# 120. sakit siku
# 121. lutut bengkak
# 122. mol kulit
# 123. lutut benjolan atau massa
# 124. kenaikan berat badan
# 125. masalah dengan gerakan
# 126. kaku lutut atau tiffness
# 127. pembengkakan kaki
# 128. kaki atau kaki bengkak
# 129. mulas
# 130. masalah merokok
# 131. otot sakit
# 132. masalah makan bayi
# 133. kehilangan berat badan terakhir
# 134. masalah dengan bentuk atau ukuran payudara
# 135. underweight
# 136. kesulitan makan
# 137. aliran menstruasi scanty
# 138. sakit vagina
# 139. redness vagina
# 140. iritasi vulvar
# 141. kelemahan
# 142. denyut jantung menurun
# 143. peningkatan detak jantung
# 144. pendarahan atau debit dari puting
# 145. dering di telinga
# 146. ditancapkan perasaan di telinga
# 147. telinga gatal
# 148. frontal sakit kepala
# 149. cairan di telinga
# 150. kaku leher atau tiffness
# 151. bintik atau awan dalam visi
# 152. redness mata
# 153. lakrimasi
# 154. itchiness mata
# 155. kebutaan
# 156. mata luka bakar atau sengatan
# 157. kelopak mata gatal
# 158. merasa dingin
# 159. nafsu makan menurun
# 160. Nafsu makan yang berlebihan
# 161. Kemarahan berlebihan.
# 162. kehilangan sensasi
# 163. focal weakness
# 164. kata slurring
# 165. gejala wajah
# 166. Gangguan memori
# 167. paresthesia
# 168. sakit samping
# 169. demam
# 170. sakit bahu
# 171. kaku bahu atau tiffness
# 172. kelemahan bahu
# 173. lengan kram atau kejang
# 174. pembengkakan bahu
# 175. lesi lidah
# 176. kram kaki atau kejang
# 177. lidah muncul abnormal
# 178. sakit seluruh
# 179. bagian bawah tubuh sakit
# 180. masalah selama kehamilan
# 181. bercak atau pendarahan selama kehamilan
# 182. Kram dan kejang
# 183. sakit perut atas
# 184. perut membengkak
# 185. perubahan dalam penampilan bangku
# 186. warna atau bau yang tidak biasa untuk urin
# 187. massa ginjal
# 188. perut bengkak
# 189. gejala prostat
# 190. kaku kaki atau tiffness
# 191. kesulitan bernapas
# 192. iga sakit
# 193. sakit sendi
# 194. otot kaku atau tiffness
# 195. pallor
# 196. tangan atau benjolan jari atau massa
# 197. menggigil
# 198. Groin sakit
# 199. kelelahan
# 200. abdominal distlets
# 201. muntah. 1
# 202. gejala ginjal
# 203. Melena
# 204. flushing
# 205. batuk sputum
# 206. kejang
# 207. delusi atau halusinasi
# 208. kram bahu atau kejang
# 209. sendi kaku atau tilf
# 210. sakit atau sakit payudara
# 211. Kencing berlebihan di malam hari
# 212. pendarahan dari mata
# 213. Rectal pendarahan
# 214. sembelit
# 215. masalah marah
# 216. coryza
# 217. kelemahan pergelangan tangan
# 218. strain mata
# 219. hemoptysis
# 220. limbridema
# 221. kulit pada kaki atau kaki terlihat terinfeksi
# 222. reaksi alergi
# 223. kemacetan di dada
# 224. pembengkakan otot
# 225. nanah dalam urin
# 226. ukuran abnormal atau bentuk telinga
# 227. kelemahan punggung rendah
# 228. Tidur
# 229. apnea
# 230. suara pernapasan abnormal
# 231. Pertumbuhan berlebihan
# 232. lutut kram atau kejang
# 233. Merasa panas dan dingin
# 234. darah pembekuan selama periode menstruasi
# 235. tidak adanya menstruasi
# 236. menarik telinga
# 237. gusi pain
# 238. kemerahan di telinga
# 239. Retensi cairan
# 240. flu- seperti sindrom
# 241. kemacetan sinus
# 242. sinus menyakitkan
# 243. ketakutan dan fobia
# 244. kehamilan terbaru
# 245. kontraksi rahim
# 246. Membakar nyeri dada
# 247. kram belakang atau kejang
# 248. kekakuan seluruh
# 249. otot kram, kontraksi, atau kejang
# 250. kram punggung rendah atau kejang
# 251. kembali massa atau benjolan
# 252. mimisan
# 253. periode menstruasi panjang
# 254. aliran menstruasi berat
# 255. menstruasi tidak terduga
# 256. Menstruasi menyakitkan
# 257. infertilitas
# 258. sering menstruasi
# 259. berkeringat
# 260. massa pada kelopak mata
# 261. mata bengkak
# 262. pembengkakan kelopak mata
# 263. lesi kelopak mata atau ruam
# 264. rambut tidak diinginkan
# 265. gejala kandung kemih
# 266. tidak teratur muncul kuku
# 267. gatal kulit
# 268. sakit untuk napas
# 269. nailbiting
# 270. kekeringan kulit, mengupas, skalaan, atau kasar
# 271. kulit pada lengan atau tangan terlihat terinfeksi
# 272. iritasi kulit
# 273. gatal kulit kepala
# 274. pembengkakan pinggul
# 275. Inkontinensi bangku
# 276. kaki atau kaki kram atau kejang
# 277. Kutil
# 278. benjolan pada penis
# 279. terlalu sedikit rambut
# 280. kaki atau benjolan jari kaki atau massa
# 281. kulit ruam
# 282. massa atau pembengkakan sekitar anus
# 283. pembengkakan punggung rendah
# 284. pembengkakan pergelangan kaki
# 285. hip benjolan atau massa
# 286. drainase di tenggorokan
# 287. atau kulit kepala yang melapisi
# 288. tegangan pra-menstruasi atau mudah iritasi
# 289. merasa panas
# 290. Kaki berbalik
# 291. kaki atau jari kaki kekakuan atau tilf
# 292. Tekanan panggul
# 293. siku pembengkakan
# 294. siku kaku atau tilf
# 295. awal atau akhir dari menopause
# 296. massa di telinga
# 297. pendarahan dari telinga
# 298. tangan atau kelemahan jari
# 299. harga diri rendah
# 300. iritasi tenggorokan
# 301. gatal anus
# 302. tonsils bengkak atau merah
# 303. tombol perut tidak teratur
# 304. lidah bengkak
# 305. bibir sakit
# 306. sakit vulvar
# 307. hip kaku atau tiffness
# 308. sakit mulut
# 309. kelemahan lengan
# 310. benjolan kaki atau massa
# 311. Gangguan bau atau rasa
# 312. discharge dalam bangku
# 313. nyeri penis
# 314. Kehilangan gairah seks
# 315. Obsesi dan dorongan
# 316. perilaku antisosial
# 317. kram leher atau kejang
# 318. murid tidak sama
# 319. sirkulasi miskin
# 320. haus
# 321. tidur berjalan
# 322. minyak kulit
# 323. bersin
# 324. Massa kandung kemih
# 325. lutut kram atau kejang.1
# 326. prematur ejakulasi
# 327. kelemahan kaki
# 328. masalah postur
# 329. pendarahan di mulut
# 330. lidah berdarah
# 331. perubahan dalam ukuran mol kulit atau warna
# 332. penis merah
# 333. penile debit
# 334. pundak benjolan atau massa
# 335. poliuria
# 336. mata berawan
# 337. perilaku histeris
# 338. benjolan lengan atau massa
# 339. mimpi buruk
# 340. Gusi berdarah
# 341. nyeri gusi
# 342. bedwetting
# 343. ruam popok
# 344. benjolan atau massa payudara
# 345. pendarahan vagina setelah menopause
# 346. menstruasi tidak sering
# 347. massa pada vulva
# 348. sakit rahang
# 349. gatal skrotum
# 350. masalah postpartum payudara
# 351. kelopak mata ditarik
# 352. keraguan
# 353. benjolan siku atau massa
# 354. kelemahan otot
# 355. Tenggorokan kemerahan
# 356. pembengkakan sendi
# 357. lidah sakit
# 358. kemerahan dalam atau sekitar hidung
# 359. Kerut pada kulit
# 360. kaki atau kaki kelemahan
# 361. tangan atau jari kram atau kejang
# 362. kembali kaku atau tiffness
# 363. benjolan pergelangan tangan atau massa
# 364. kulit sakit
# 365. kaku punggung rendah atau tiffness
# 366. keluaran urin rendah
# 367. kulit di kepala atau leher terlihat terinfeksi
# 368. gagap atau gagap
# 369. masalah dengan orgasme
# 370. deformitas hidung
# 371. benjolan di atas rahang
# 372. sakit di hidung
# 373. kelemahan pinggul
# 374. pembengkakan belakang
# 375. Pergelangan kaki kaku atau tiffness
# 376. Pergelangan kaki kelemahan
# 377. kelemahan leher
# 378. kaki_bengkak
# 379. penyusutan_otot
# 380. hidung_tersumbat
# 381. cairan_kerak_kuning
# 382. riwayat_keluarga
# 383. memar
# 384. sakit_perut
# 385. tekanan_sinus
# 386. jantung_berdebar
# 387. mata_menguning
# 388. nyeri_saat_buang_air_kecil
# 389. nyeri_dada
# 390. bercak_di_tenggorokan
# 391. serpihan_seperti_perak
# 392. sakit_kepala
# 393. kuku_rapuh
# 394. nyeri_di_daerah_anus
# 395. tidak_bernama
# 396. hubungan_di_luar_nikah
# 397. hilangnya_penciuman
# 398. kelemahan_anggota_tubuh
# 399. demam_ringan
# 400. nyeri_sendi_pinggul
# 401. gatal
# 402. hidung_meler
# 403. mata_merah
# 404. urin_kuning
# 405. gangguan_penglihatan
# 406. iritasi_tenggorokan
# 407. nyeri_leher
# 408. kelebihan_cairan
# 409. kekakuan_gerakan
# 410. lekukan_kecil_di_kuku
# 411. mata_cekung
# 412. lesu
# 413. darah_dalam_dahak
# 414. kadar_gula_tidak_stabil
# 415. nyeri_perut.1
# 416. kurang_konsentrasi
# 417. dahak
# 418. bintil_pada_kulit
# 419. wajah_dan_mata_bengkak
# 420. pembesaran_tiroid
# 421. nyeri_perut
# 422. buang_gas
# 423. sesak_napas
# 424. detak_jantung_cepat
# 425. bibir_kering_dan_kesemutan
# 426. jerawat_bernanah
# 427. kehilangan_keseimbangan
# 428. menerima_suntikan_tidak_steril
# 429. ketidakstabilan
# 430. bercak_darah_saat_buang_air_kecil
# 431. kelebihan_cairan.1
# 432. gagal_hati_akut
# 433. riwayat_konsumsi_alkohol
# 434. rasa_tidak_enak_badan
# 435. leher_kaku
# 436. perubahan_suasana_hati
# 437. luka_merah_di_sekitar_hidung
# 438. menstruasi_tidak_normal
# 439. dahak_berlendir
# 440. nafsu_makan_meningkat
# 441. cemas
# 442. bersin_terus_menerus
# 443. koma
# 444. gelisah
# 445. kelemahan_satu_sisi_tubuh
# 446. buang_air_kecil_berlebihan
# 447. sariawan_di_lidah
# 448. penglihatan_kabur_dan_terganggu
# 449. tinja_berdarah
# 450. bercak_warna_kulit_tidak_merata
# 451. nyeri_sendi
# 452. urin_gelap
# 453. kelemahan_otot
# 454. komedo_hitam
# 455. kulit_mengelupas
# 456. meriang
# 457. dehidrasi
# 458. penurunan_berat_badan
# 459. pembengkakan_anggota_tubuh
# 460. pembuluh_darah_menonjol_di_betis
# 461. pembuluh_darah_bengkak
# 462. iritasi_di_anus
# 463. lapar_berlebihan
# 464. lepuh
# 465. hilang_nafsu_makan
# 466. pembengkakan_perut
# 467. koreng
# 468. mata_berair
# 469. demam_tinggi
# 470. bintik_merah_di_tubuh
# 471. asam_lambung
# 472. kesadaran_berubah
# 473. nyeri_lutut
# 474. nyeri_punggung
# 475. gangguan_pencernaan
# 476. ketidaknyamanan_kandung_kemih
# 477. pendarahan_lambung
# 478. tampilan_toksik_seperti_tifus
# 479. pernah_transfusi_darah
# 480. mudah_marah
# 481. nyeri_di_belakang_mata
# 482. bicara_pelo
# 483. kulit_kekuningan
# 484. nyeri_otot
# 485. sendi_bengkak
# 486. perut_membesar
# 487. pembengkakan_kelenjar_getah_bening
# 488. nyeri_saat_buang_air_besar
# 489. bau_urin_tidak_sedap
# 490. kenaikan_berat_badan
# 491. kram
# 492. gatal_dalam_tubuh
# 493. dahak_berwarna_karat
# 494. obesitas
# 495. nyeri_saat_berjalan
# 496. terus_ingin_buang_air_kecil
# 497. ruam_kulit
# 498. tangan_dan_kaki_dingin
# 499. kuku_meradang
# 500. sensasi_berputar
#
# === Hasil Prediksi Penyakit ===
# Penyakit yang diprediksi: GANGGUAN PANIK
# c:\Users\crism\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
